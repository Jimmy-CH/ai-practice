# %%
"""
4.1.4 Pandas 数据清洗培训大纲编写
1. 掌握Pandas的基本功能，学会安装和配置Pandas，能够读取和保存不同格式的数据
2. 掌握数据筛选、去重和缺失值处理的方法，提高数据质量。
3. 掌握数据类型转换、时间序列处理及数据分列与合并的方法，提升数据处理能力。
4. 掌握数据合并与重塑的技术，能够有效组织和转换数据格式
5. 掌握数据分组与聚合的基本方法，提高数据分析能力
"""
