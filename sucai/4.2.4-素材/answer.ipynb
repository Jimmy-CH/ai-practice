# %%
"""
4.2.4自动驾驶汽车感知系统数据采集与标注指导方案
1. 结合摄像头、激光雷达（LiDAR）、毫米波雷达、GPS 和 IMU 等多种传感器，实现全面的环境感知。

2. 覆盖城市道路、高速公路、隧道、雨雪天、夜间等多种典型驾驶场景，确保数据多样性与泛化能力

3.设置传感器校准流程，过滤模糊、过曝、传感器失效等无效数据，确保采集数据的可用性和一致性。

4.标注员培训

5. 高质量结构化_
"""
