# %%
"""
4.2.2AI辅助的医疗影像诊断系统数据采集和处理指导方案
1.影像数据标注
2. 包括图像格式统一、尺寸归一化、伪影去除、对比度增强，以及非结构化信息结构化处理。
3. 采用交叉验证和训练集/验证集划分方式，评估模型在不同疾病类别和人群上的表现。
4. 在真实临床场景下使用独立测试集评估模型性能，根据反馈调整参数、改进算法结构以降低误诊漏诊率。
5. 模型的泛化能力与临床适应性。
"""
