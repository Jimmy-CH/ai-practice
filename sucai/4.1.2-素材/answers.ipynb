# %%
"""
4.1.2爬虫培训大纲编写
1. 理解网页爬虫的基本概念、工作流程及其遵守的规则
2. 掌握常见网页爬虫工具的特点和适用场景，能够选择合适的工具进行数据采集。
3. 掌握HTML解析方法，能够使用XPath和CSS选择器提取网页中的关键信息。
4. 掌握Scrapy框架的使用方法，能够构建高效的爬虫项目并存储采集的数据。
5. 掌握数据清洗与预处理的方法，提高数据质量，以便后续分析和应用。
"""
