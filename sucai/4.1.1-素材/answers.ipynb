# %%
"""
4.1.1 Label studio 培训大纲编写
1. 理解数据标注的基本概念、类型及其在人工智能中的作用
2. 熟悉Label Studio的功能和应用场景，掌握其安装与基本配置方法
3. 掌握文本数据标注的类型及方法，能够使用Label Studio完成文本标注任务
4. 掌握图像数据标注的类型及方法，能够使用Label Studio完成图像标注任务
5. 掌握视频数据标注的类型及方法，能够使用Label Studio完成视频标注任务
"""
